# %%
from src import training_examples
# Out:
# Running cells with 'artems (Python 3.12.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/workspace/arteml/artems/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !uv pip install ipykernel
# Out:
# Running cells with 'artems (Python 3.12.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/workspace/arteml/artems/bin/python -m pip install ipykernel -U --force-reinstall'
